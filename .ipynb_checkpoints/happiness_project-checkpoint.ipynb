# %%
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ## Data exploration & Columns removal

# %%
home_path = ('/Users/malikatapparel/Documents/AlUni/Master/cours/DS/full_example/')
data_dir = os.path.join(home_path, 'happiness_project/')
wh_data_path = os.path.join(data_dir, 'WHR20_DataForTable2.1.xls')
wh_data_path
# Out:
# '/Users/malikatapparel/Documents/AlUni/Master/cours/DS/full_example/happiness_project/WHR20_DataForTable2.1.xls'

# %%
#Read dataframe
wh_all_df = pd.read_excel(wh_data_path)

# %%
wh_all_df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.144916        0.450662
# 1     Afghanistan  2009     4.401778            7.314788        0.552308
# 2     Afghanistan  2010     4.758381            7.421525        0.539075
# 3     Afghanistan  2011     3.831719            7.394349        0.521104
# 4     Afghanistan  2012     3.782938            7.480296        0.520637
# ...           ...   ...          ...                 ...             ...
# 1843     Zimbabwe  2015     3.703191            7.827643        0.735800
# 1844     Zimbabwe  2016     3.735400            7.819675        0.768425
# 1845     Zimbabwe  2017     3.638300            7.851042        0.754147
# 1846     Zimbabwe  2018     3.616480            7.896704        0.775388
# 1847     Zimbabwe  2019     2.693523            7.850442        0.759162
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                            50.799999                      0.718114
# 1                            51.200001                      0.678896
# 2                            51.599998                      0.600127
# 3                            51.919998                      0.495901
# 4                            52.240002                      0.530935
# ...                                ...                           ...
# 1843                         53.799999                      0.667193
# 1844                         54.400002                      0.732971
# 1845                         55.000000                      0.752826
# 1846                         55.599998                      0.762675
# 1847                         56.200001                      0.631908
#
#       Generosity  Perceptions of corruption  Positive affect  ...  \
# 0       0.178993                   0.881686         0.517637  ...
# 1       0.201228                   0.850035         0.583926  ...
# 2       0.131578                   0.706766         0.618265  ...
# 3       0.173452                   0.731109         0.611387  ...
# 4       0.246943                   0.775620         0.710385  ...
# ...          ...                        ...              ...  ...
# 1843   -0.117035                   0.810457         0.715079  ...
# 1844   -0.088488                   0.723612         0.737636  ...
# 1845   -0.091540                   0.751208         0.806428  ...
# 1846   -0.063282                   0.844209         0.710119  ...
# 1847   -0.062325                   0.830652         0.716004  ...
#
#       GINI index (World Bank estimate)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 1843                               NaN
# 1844                               NaN
# 1845                               NaN
# 1846                               NaN
# 1847                               NaN
#
#       GINI index (World Bank estimate), average 2000-2017, unbalanced panel  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1843                                              0.432
# 1844                                              0.432
# 1845                                              0.432
# 1846                                              0.432
# 1847                                              0.432
#
#       gini of household income reported in Gallup, by wp5-year  \
# 0                                                   NaN
# 1                                              0.441906
# 2                                              0.327318
# 3                                              0.336764
# 4                                              0.344540
# ...                                                 ...
# 1843                                           0.655137
# 1844                                           0.596690
# 1845                                           0.581484
# 1846                                           0.541772
# 1847                                           0.699588
#
#       Most people can be trusted, Gallup  \
# 0                                    NaN
# 1                               0.286315
# 2                               0.275833
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 1843                                 NaN
# 1844                                 NaN
# 1845                                 NaN
# 1846                                 NaN
# 1847                                 NaN
#
#       Most people can be trusted, WVS round 1981-1984  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1843                                              NaN
# 1844                                              NaN
# 1845                                              NaN
# 1846                                              NaN
# 1847                                              NaN
#
#       Most people can be trusted, WVS round 1989-1993  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1843                                              NaN
# 1844                                              NaN
# 1845                                              NaN
# 1846                                              NaN
# 1847                                              NaN
#
#       Most people can be trusted, WVS round 1994-1998  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1843                                              NaN
# 1844                                              NaN
# 1845                                              NaN
# 1846                                              NaN
# 1847                                              NaN
#
#       Most people can be trusted, WVS round 1999-2004  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1843                                         0.116683
# 1844                                         0.116683
# 1845                                         0.116683
# 1846                                         0.116683
# 1847                                         0.116683
#
#       Most people can be trusted, WVS round 2005-2009  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1843                                              NaN
# 1844                                              NaN
# 1845                                              NaN
# 1846                                              NaN
# 1847                                              NaN
#
#       Most people can be trusted, WVS round 2010-2014
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1843                                         0.082942
# 1844                                         0.082942
# 1845                                         0.082942
# 1846                                         0.082942
# 1847                                         0.082942
#
# [1848 rows x 26 columns]

# %%
#new df only with columns of interest
wh_all_df.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect',
#        'Confidence in national government', 'Democratic Quality',
#        'Delivery Quality', 'Standard deviation of ladder by country-year',
#        'Standard deviation/Mean of ladder by country-year',
#        'GINI index (World Bank estimate)',
#        'GINI index (World Bank estimate), average 2000-2017, unbalanced panel',
#        'gini of household income reported in Gallup, by wp5-year',
#        'Most people can be trusted, Gallup',
#        'Most people can be trusted, WVS round 1981-1984',
#        'Most people can be trusted, WVS round 1989-1993',
#        'Most people can be trusted, WVS round 1994-1998',
#        'Most people can be trusted, WVS round 1999-2004',
#        'Most people can be trusted, WVS round 2005-2009',
#        'Most people can be trusted, WVS round 2010-2014'],
#       dtype='object')

# %%
cols_of_interest = wh_all_df.columns[1:9]
cols_of_interest
# Out:
# Index(['year', 'Life Ladder', 'Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption'],
#       dtype='object')

# %%
#plot the data to explore
# %matplotlib inline

# %%
wh_withna_df = wh_all_df[cols_of_interest]
wh_withna_df
# Out:
#       year  Life Ladder  Log GDP per capita  Social support  \
# 0     2008     3.723590            7.144916        0.450662
# 1     2009     4.401778            7.314788        0.552308
# 2     2010     4.758381            7.421525        0.539075
# 3     2011     3.831719            7.394349        0.521104
# 4     2012     3.782938            7.480296        0.520637
# ...    ...          ...                 ...             ...
# 1843  2015     3.703191            7.827643        0.735800
# 1844  2016     3.735400            7.819675        0.768425
# 1845  2017     3.638300            7.851042        0.754147
# 1846  2018     3.616480            7.896704        0.775388
# 1847  2019     2.693523            7.850442        0.759162
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                            50.799999                      0.718114
# 1                            51.200001                      0.678896
# 2                            51.599998                      0.600127
# 3                            51.919998                      0.495901
# 4                            52.240002                      0.530935
# ...                                ...                           ...
# 1843                         53.799999                      0.667193
# 1844                         54.400002                      0.732971
# 1845                         55.000000                      0.752826
# 1846                         55.599998                      0.762675
# 1847                         56.200001                      0.631908
#
#       Generosity  Perceptions of corruption
# 0       0.178993                   0.881686
# 1       0.201228                   0.850035
# 2       0.131578                   0.706766
# 3       0.173452                   0.731109
# 4       0.246943                   0.775620
# ...          ...                        ...
# 1843   -0.117035                   0.810457
# 1844   -0.088488                   0.723612
# 1845   -0.091540                   0.751208
# 1846   -0.063282                   0.844209
# 1847   -0.062325                   0.830652
#
# [1848 rows x 8 columns]

# %%
sns.pairplot(wh_withna_df)

# %% [markdown]
# ## NA treatment

# %%
#Count the NA
wh_withna_df.isna().sum()
# Out:
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   29
# Social support                       13
# Healthy life expectancy at birth     52
# Freedom to make life choices         31
# Generosity                           83
# Perceptions of corruption           103
# dtype: int64

# %% [raw]
# #Adressing NA: here not done because wants to have the same results as the teacher
# log_GDP_per_capita_median = wh_withna_df['Log GDP per capita'].median()
# log_GDP_per_capita_median
# wh_withna_df['Log GDP per capita'] = wh_withna_df['Log GDP per capita'].fillna(log_GDP_per_capita_median)

# %% [raw]
# wh_withna_df.isna().sum()

# %% [raw]
# healthy_median = wh_withna_df['Healthy life expectancy at birth'].median()
# wh_withna_df['Healthy life expectancy at birth'] = wh_withna_df['Healthy life expectancy at birth'].fillna(healthy_median)

# %% [raw]
# wh_withna_df.isna().sum()

# %%
wh_df = wh_withna_df.dropna()

# %%
wh_df.isna().sum()
# Out:
# year                                0
# Life Ladder                         0
# Log GDP per capita                  0
# Social support                      0
# Healthy life expectancy at birth    0
# Freedom to make life choices        0
# Generosity                          0
# Perceptions of corruption           0
# dtype: int64

# %%
len(wh_df)
# Out:
# 1627

# %%
sns.pairplot(wh_df)

# %%
mask_year = (wh_df['year'] < 2018) & (wh_df['year'] >= 2006)

# %%
wh_df.columns
# Out:
# Index(['year', 'Life Ladder', 'Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption'],
#       dtype='object')

# %%
wh_df_wo_ladder = wh_df[['year', 'Log GDP per capita', 'Social support',
       'Healthy life expectancy at birth', 'Freedom to make life choices',
       'Generosity', 'Perceptions of corruption']]

# %%
X_train_df = wh_df_wo_ladder[mask_year]

# %%
wh_df_ladder = wh_df[['Life Ladder']]
y_train_df = wh_df_ladder[mask_year]

# %%
mask_year_test = wh_df['year'] == 2019

# %%
X_test_df = wh_df_wo_ladder[mask_year_test]
y_test_df = wh_df_ladder[mask_year_test]

# %%
    wh_df_wo_ladder = wh_df[['year', 'Log GDP per capita', 'Social support',
       'Healthy life expectancy at birth', 'Freedom to make life choices',
       'Generosity', 'Perceptions of corruption']]
    wh_df_ladder = wh_df[['Life Ladder']]
    mask_year = (wh_df['year'] < 2018)
    X_train_df = wh_df_wo_ladder[mask_year]
    y_train_df = wh_df_ladder[mask_year]
    mask_year_test = wh_df['year'] == 2019
    X_test_df = wh_df_wo_ladder[mask_year_test]
    y_test_df = wh_df_ladder[mask_year_test]

# %%
X_train_path = os.path.join(data_dir, 'X_train_df.csv')
y_train_path = os.path.join(data_dir, 'y_train_df.csv')
X_test_path = os.path.join(data_dir, 'X_test_df.csv')
y_test_path = os.path.join(data_dir, 'y_test_df.csv')

# %%
X_train_df.to_csv(X_train_path, index=False)
y_train_df.to_csv(y_train_path, index=False)
X_test_df.to_csv(X_test_path, index=False)
y_test_df.to_csv(y_test_path, index=False)

# %%
def hello():
    X_train_path = os.path.join(data_dir, 'X_train_df.csv')
    y_train_path = os.path.join(data_dir, 'y_train_df.csv')
    return(X_train_path, y_train_path)

# %%
hello()
# Out:
# ('/Users/malikatapparel/Documents/AlUni/Master/cours/DS/full_example/happiness_project/X_train_df.csv',
#  '/Users/malikatapparel/Documents/AlUni/Master/cours/DS/full_example/happiness_project/y_train_df.csv')
